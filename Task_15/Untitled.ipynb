# %% [markdown]
# # Hierarchical Indexing

# %%
import numpy as np
import pandas as pd
data = pd.Series(np.random.randn(9),
                 index = [['a', 'b', 'c', 'd', 'a', 'b', 'c', 'd', 'a'],
                          [1,2,3,1,2,3,1,2,3]])
print(data)
# Out:
# a  1   -2.050091
# b  2   -0.541113
# c  3   -0.510693
# d  1   -0.729205
# a  2   -0.387490
# b  3    0.083869
# c  1   -1.509421
# d  2   -0.187547
# a  3    1.229925
# dtype: float64

# %%
data.index
# Out:
# MultiIndex([('a', 1),
#             ('b', 2),
#             ('c', 3),
#             ('d', 1),
#             ('a', 2),
#             ('b', 3),
#             ('c', 1),
#             ('d', 2),
#             ('a', 3)],
#            )

# %%
print (data['b'])
#print (data['b':'c'])
print (data.loc[['b','d']])
# Out:
# 2   -0.541113
# 3    0.083869
# dtype: float64
# b  2   -0.541113
#    3    0.083869
# d  1   -0.729205
#    2   -0.187547
# dtype: float64

# %%
data.loc[:, 2]
# Out:
# b   -0.541113
# a   -0.387490
# d   -0.187547
# dtype: float64

# %%
print (data)
data.unstack()
# Out:
# a  1   -2.050091
# b  2   -0.541113
# c  3   -0.510693
# d  1   -0.729205
# a  2   -0.387490
# b  3    0.083869
# c  1   -1.509421
# d  2   -0.187547
# a  3    1.229925
# dtype: float64
#           1         2         3
# a -2.050091 -0.387490  1.229925
# b       NaN -0.541113  0.083869
# c -1.509421       NaN -0.510693
# d -0.729205 -0.187547       NaN

# %%
data.unstack().stack()
# Out:
# a  1   -2.050091
#    2   -0.387490
#    3    1.229925
# b  2   -0.541113
#    3    0.083869
# c  1   -1.509421
#    3   -0.510693
# d  1   -0.729205
#    2   -0.187547
# dtype: float64

# %%
import pandas as pd
import numpy as np

frame = pd.DataFrame(np.arange(12).reshape((4, 3)),
                     index=[['a', 'a', 'b', 'b'], [1, 2, 1, 2]],
                     columns=[["Islamabad", "Islamabad", "Lahore"],
                              ["Green", "Red", "Green"]])
print(frame)
# Out:
#     Islamabad     Lahore
#         Green Red  Green
# a 1         0   1      2
#   2         3   4      5
# b 1         6   7      8
#   2         9  10     11

# %%
frame.index.names = ['key1', 'key2']
frame.columns.names = ['state', 'color']
print (frame)
# Out:
# state     Islamabad     Lahore
# color         Green Red  Green
# key1 key2
# a    1            0   1      2
#      2            3   4      5
# b    1            6   7      8
#      2            9  10     11

# %%
frame ['Islamabad']
# Out:
# color      Green  Red
# key1 key2
# a    1         0    1
#      2         3    4
# b    1         6    7
#      2         9   10

# %% [markdown]
# ## Reordering and Sorting Levels

# %%
frame.swaplevel ('key1', 'key2')
# Out:
# state     Islamabad     Lahore
# color         Green Red  Green
# key2 key1
# 1    a            0   1      2
# 2    a            3   4      5
# 1    b            6   7      8
# 2    b            9  10     11

# %%
frame.sort_index(level = 1)
frame.swaplevel(0, 1).sort_index(level = 0)
# Out:
# state     Islamabad     Lahore
# color         Green Red  Green
# key2 key1
# 1    a            0   1      2
#      b            6   7      8
# 2    a            3   4      5
#      b            9  10     11

# %% [markdown]
# ## Combining and Merging Datasets

# %% [markdown]
# ### Databases-Style DataFrame Joins

# %%
df1 = pd.DataFrame ({'key': ['b','b', 'a', 'c', 'a', 'a', 'b'],
                    'data1': range(7)})
df2 = pd.DataFrame ({'key': ['a', 'b', 'd'],
                     'data2': range(3)})
df1
df2
# Out:
#   key  data2
# 0   a      0
# 1   b      1
# 2   d      2

# %%
pd.merge(df1, df2)
# Out:
#   key  data1  data2
# 0   b      0      1
# 1   b      1      1
# 2   b      6      1
# 3   a      2      0
# 4   a      4      0
# 5   a      5      0

# %%
pd.merge(df1, df2, on='key')
# Out:
#   key  data1  data2
# 0   b      0      1
# 1   b      1      1
# 2   b      6      1
# 3   a      2      0
# 4   a      4      0
# 5   a      5      0

# %%
df3 = pd.DataFrame ({'lkey': ['b','b', 'a', 'c', 'a', 'a', 'b'],
                    'data1': range(7)})
df4 = pd.DataFrame ({'rkey': ['a', 'b', 'd'],
                     'data2': range(3)})
pd.merge (df3, df4, left_on = 'lkey', right_on = 'rkey')
# Out:
#   lkey  data1 rkey  data2
# 0    b      0    b      1
# 1    b      1    b      1
# 2    b      6    b      1
# 3    a      2    a      0
# 4    a      4    a      0
# 5    a      5    a      0

# %%
pd.merge(df1, df2, how = 'outer')
# Out:
#   key  data1  data2
# 0   b    0.0    1.0
# 1   b    1.0    1.0
# 2   b    6.0    1.0
# 3   a    2.0    0.0
# 4   a    4.0    0.0
# 5   a    5.0    0.0
# 6   c    3.0    NaN
# 7   d    NaN    2.0

# %%
df1 = pd.DataFrame ({'key': ['b','b', 'a', 'c', 'a', 'b'],
                    'data1': range(6)})
df2 = pd.DataFrame ({'key': ['a', 'b', 'd', 'a', 'b'],
                     'data2': range(5)})

df1
df2
pd.merge (df1, df2, on = 'key', how = 'left')
# Out:
#    key  data1  data2
# 0    b      0    1.0
# 1    b      0    4.0
# 2    b      1    1.0
# 3    b      1    4.0
# 4    a      2    0.0
# 5    a      2    3.0
# 6    c      3    NaN
# 7    a      4    0.0
# 8    a      4    3.0
# 9    b      5    1.0
# 10   b      5    4.0

# %%
pd.merge(df1, df2, how = 'inner')
# Out:
#   key  data1  data2
# 0   b      0      1
# 1   b      0      4
# 2   b      1      1
# 3   b      1      4
# 4   b      5      1
# 5   b      5      4
# 6   a      2      0
# 7   a      2      3
# 8   a      4      0
# 9   a      4      3

# %% [markdown]
# ### Merging on Index

# %%
left1 = pd.DataFrame({'key': ['a', 'b', 'a', 'a', 'b', 'c'],
                      'value': range(6)})
right1 = pd.DataFrame({'group_val': [3.5, 7]}, index = ['a', 'b'])
left1
right1
pd.merge(left1, right1, left_on = 'key', right_index = True)
# Out:
#   key  value  group_val
# 0   a      0        3.5
# 2   a      2        3.5
# 3   a      3        3.5
# 1   b      1        7.0
# 4   b      4        7.0

# %% [markdown]
# #  Data Wrangling: Join, Combine, and Reshape.

# %% [markdown]
# ### Merge two DataFrames on a single key.

# %%
import pandas as pd
import numpy as np


df1 = pd.DataFrame({'key': ['A', 'B', 'C'], 
                    'value1': [1, 2, 3]})
df2 = pd.DataFrame({'key': ['A', 'B', 'D'], 
                    'value2': [4, 5, 6]})


merged_df = pd.merge(df1, df2, on='key')
print("Merge on single key:\n", merged_df)
# Out:
# Merge on single key:
#    key  value1  value2
# 0   A       1       4
# 1   B       2       5

# %% [markdown]
# ### Merge two DataFrames on multiple keys

# %%
df1 = pd.DataFrame({'key1': ['A', 'B', 'C'], 
                    'key2': ['X', 'Y', 'Z'], 
                    'value1': [1, 2, 3]})
df2 = pd.DataFrame({'key1': ['A', 'B', 'D'], 
                    'key2': ['X', 'Y', 'W'], 
                    'value2': [4, 5, 6]})


merged_df = pd.merge(df1, df2, on = ['key1', 'key2'])
print("Merge on multiple keys:\n", merged_df)
# Out:
# Merge on multiple keys:
#    key1 key2  value1  value2
# 0    A    X       1       4
# 1    B    Y       2       5

# %% [markdown]
# ### Perform different types of joins

# %%
outer_join = pd.merge(df1, df2, on=['key1', 'key2'], how='outer')
print("Outer join:\n", outer_join)
# Out:
# Outer join:
#    key1 key2  value1  value2
# 0    A    X     1.0     4.0
# 1    B    Y     2.0     5.0
# 2    C    Z     3.0     NaN
# 3    D    W     NaN     6.0

# %%
inner_join = pd.merge(df1, df2, on=['key1', 'key2'], how='inner')
print("Inner join:\n", inner_join)
# Out:
# Inner join:
#    key1 key2  value1  value2
# 0    A    X       1       4
# 1    B    Y       2       5

# %%
left_join = pd.merge(df1, df2, on=['key1', 'key2'], how='left')
print("Left join:\n", left_join)
# Out:
# Left join:
#    key1 key2  value1  value2
# 0    A    X       1     4.0
# 1    B    Y       2     5.0
# 2    C    Z       3     NaN

# %%
right_join = pd.merge(df1, df2, on=['key1', 'key2'], how='right')
print("Right join:\n", right_join)
# Out:
# Right join:
#    key1 key2  value1  value2
# 0    A    X     1.0       4
# 1    B    Y     2.0       5
# 2    D    W     NaN       6

# %%
df1 = pd.DataFrame({'A': ['A0', 'A1', 'A2'], 
                    'B': ['B0', 'B1', 'B2']})
df2 = pd.DataFrame({'A': ['A3', 'A4', 'A5'], 
                    'B': ['B3', 'B4', 'B5']})

concat_rows = pd.concat([df1, df2], axis=0)
print("Concatenate along rows:\n", concat_rows)
# Out:
# Concatenate along rows:
#      A   B
# 0  A0  B0
# 1  A1  B1
# 2  A2  B2
# 0  A3  B3
# 1  A4  B4
# 2  A5  B5

# %% [markdown]
# ### Concatenate two DataFrames along columns

# %%
df1 = pd.DataFrame({'A': ['A0', 'A1', 'A2']})
df2 = pd.DataFrame({'B': ['B0', 'B1', 'B2']})

concat_cols = pd.concat([df1, df2], axis=1)
print("Concatenate along columns:\n", concat_cols)
# Out:
# Concatenate along columns:
#      A   B
# 0  A0  B0
# 1  A1  B1
# 2  A2  B2

# %% [markdown]
# ### Concatenate a list of DataFrames

# %%
dfs = [df1, df2, df1]

concat_list = pd.concat(dfs)
print("Concatenate list of DataFrames:\n", concat_list)
# Out:
# Concatenate list of DataFrames:
#       A    B
# 0   A0  NaN
# 1   A1  NaN
# 2   A2  NaN
# 0  NaN   B0
# 1  NaN   B1
# 2  NaN   B2
# 0   A0  NaN
# 1   A1  NaN
# 2   A2  NaN

# %% [markdown]
# ### Reshape data using the melt function to go from wide to long format

# %%
df = pd.DataFrame({'ID': [1, 2, 3], 
                   'Math': [90, 80, 70], 
                   'Science': [85, 75, 95]})

melted_df = pd.melt(df, id_vars=['ID'], 
                    value_vars=['Math', 'Science'], 
                    var_name='Subject', 
                    value_name='Score')
print("Melted DataFrame:\n", melted_df)
# Out:
# Melted DataFrame:
#     ID  Subject  Score
# 0   1     Math     90
# 1   2     Math     80
# 2   3     Math     70
# 3   1  Science     85
# 4   2  Science     75
# 5   3  Science     95

# %% [markdown]
# ### Create a pivot table to summarize data

# %%
df = pd.DataFrame({'ID': [1, 2, 3, 1, 2, 3], 
                   'Subject': ['Math', 'Math', 'Math', 'Science', 'Science', 'Science'], 
                   'Score': [90, 80, 70, 85, 75, 95]})

pivot_table = df.pivot_table(values='Score', 
                             index='ID', 
                             columns='Subject', 
                             aggfunc='mean')
print("Pivot table:\n", pivot_table)
# Out:
# Pivot table:
#  Subject  Math  Science
# ID
# 1        90.0     85.0
# 2        80.0     75.0
# 3        70.0     95.0

# %% [markdown]
# ### Group data by one or more columns and perform aggregation functions

# %%
grouped_sum = df.groupby(['ID', 'Subject'])['Score'].sum()
print("Grouped sum:\n", grouped_sum)
# Out:
# Grouped sum:
#  ID  Subject
# 1   Math       90
#     Science    85
# 2   Math       80
#     Science    75
# 3   Math       70
#     Science    95
# Name: Score, dtype: int64

# %% [markdown]
# ### Apply multiple aggregation functions to grouped data

# %%
grouped_agg = df.groupby('Subject')['Score'].agg(['mean', 'sum', 'count'])
print("Grouped with multiple aggregations:\n", grouped_agg)
# Out:
# Grouped with multiple aggregations:
#           mean  sum  count
# Subject
# Math     80.0  240      3
# Science  85.0  255      3

# %% [markdown]
# ### Use the groupby function to group data and apply custom functions

# %%
def custom_func(x):
    return x.max() - x.min()

grouped_custom = df.groupby('Subject')['Score'].apply(custom_func)
print("Grouped with custom function:\n", grouped_custom)
# Out:
# Grouped with custom function:
#  Subject
# Math       20
# Science    20
# Name: Score, dtype: int64

# %% [markdown]
# # Mini Project using the above concepts

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv ("heart.csv")

# %%
df
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0     63    1   3     145   233    1        0       150     0      2.3    0
# 1     37    1   2     130   250    0        1       187     0      3.5    0
# 2     41    0   1     130   204    0        0       172     0      1.4    2
# 3     56    1   1     120   236    0        1       178     0      0.8    2
# 4     57    0   0     120   354    0        1       163     1      0.6    2
# ..   ...  ...  ..     ...   ...  ...      ...       ...   ...      ...  ...
# 298   57    0   0     140   241    0        1       123     1      0.2    1
# 299   45    1   3     110   264    0        1       132     0      1.2    1
# 300   68    1   0     144   193    1        1       141     0      3.4    1
# 301   57    1   0     130   131    0        1       115     1      1.2    1
# 302   57    0   1     130   236    0        0       174     0      0.0    1
#
#      caa  thall  output
# 0      0      1       1
# 1      0      2       1
# 2      0      2       1
# 3      0      2       1
# 4      0      2       1
# ..   ...    ...     ...
# 298    0      3       0
# 299    0      3       0
# 300    2      3       0
# 301    1      3       0
# 302    1      2       0
#
# [303 rows x 14 columns]

# %%
df.head()
# Out:
#    age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0   63    1   3     145   233    1        0       150     0      2.3    0
# 1   37    1   2     130   250    0        1       187     0      3.5    0
# 2   41    0   1     130   204    0        0       172     0      1.4    2
# 3   56    1   1     120   236    0        1       178     0      0.8    2
# 4   57    0   0     120   354    0        1       163     1      0.6    2
#
#    caa  thall  output
# 0    0      1       1
# 1    0      2       1
# 2    0      2       1
# 3    0      2       1
# 4    0      2       1

# %%
df.tail()
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 298   57    0   0     140   241    0        1       123     1      0.2    1
# 299   45    1   3     110   264    0        1       132     0      1.2    1
# 300   68    1   0     144   193    1        1       141     0      3.4    1
# 301   57    1   0     130   131    0        1       115     1      1.2    1
# 302   57    0   1     130   236    0        0       174     0      0.0    1
#
#      caa  thall  output
# 298    0      3       0
# 299    0      3       0
# 300    2      3       0
# 301    1      3       0
# 302    1      2       0

# %%
df.set_index('age', inplace=True)
df.head()
# Out:
#      sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  caa  \
# age
# 63     1   3     145   233    1        0       150     0      2.3    0    0
# 37     1   2     130   250    0        1       187     0      3.5    0    0
# 41     0   1     130   204    0        0       172     0      1.4    2    0
# 56     1   1     120   236    0        1       178     0      0.8    2    0
# 57     0   0     120   354    0        1       163     1      0.6    2    0
#
#      thall  output
# age
# 63       1       1
# 37       2       1
# 41       2       1
# 56       2       1
# 57       2       1

# %%
cp_series = df['cp']
cp_series.head()
# Out:
# age
# 63    3
# 37    2
# 41    1
# 56    1
# 57    0
# Name: cp, dtype: int64

# %%
selected_columns = df[['sex', 'cp', 'chol']]
selected_columns.head()
# Out:
#      sex  cp  chol
# age
# 63     1   3   233
# 37     1   2   250
# 41     0   1   204
# 56     1   1   236
# 57     0   0   354

# %%
subset_iloc = df.iloc[0:5, 0:3]
subset_iloc
# Out:
#      sex  cp  trtbps
# age
# 63     1   3     145
# 37     1   2     130
# 41     0   1     130
# 56     1   1     120
# 57     0   0     120

# %%
filtered_df = df[df['chol'] > 200]
filtered_df.head()
# Out:
#      sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  caa  \
# age
# 63     1   3     145   233    1        0       150     0      2.3    0    0
# 37     1   2     130   250    0        1       187     0      3.5    0    0
# 41     0   1     130   204    0        0       172     0      1.4    2    0
# 56     1   1     120   236    0        1       178     0      0.8    2    0
# 57     0   0     120   354    0        1       163     1      0.6    2    0
#
#      thall  output
# age
# 63       1       1
# 37       2       1
# 41       2       1
# 56       2       1
# 57       2       1

# %%
grouped_mean = df.groupby('sex').mean()
grouped_mean
# Out:
#            cp      trtbps        chol      fbs   restecg    thalachh  \
# sex
# 0    1.041667  133.083333  261.302083  0.12500  0.572917  151.125000
# 1    0.932367  130.946860  239.289855  0.15942  0.507246  148.961353
#
#          exng   oldpeak       slp       caa     thall    output
# sex
# 0    0.229167  0.876042  1.427083  0.552083  2.125000  0.750000
# 1    0.371981  1.115459  1.386473  0.811594  2.400966  0.449275

# %%
grouped_sum = df.groupby(['sex', 'cp']).sum()
grouped_sum
# Out:
#         trtbps   chol  fbs  restecg  thalachh  exng  oldpeak  slp  caa  thall  \
# sex cp
# 0   0     5405  10434    5       21      5666    18     52.9   46   32     89
#     1     2305   4526    2       10      2931     2      8.3   30   10     36
#     2     4476   9137    4       21      5313     2     16.6   55    9     71
#     3      590    988    1        3       598     0      6.3    6    2      8
# 1   0    13474  25335   13       47     14431    62    144.9  134  106    261
#     1     4115   7713    3       21      5190     2      7.5   54   11     71
#     2     6867  12019   13       31      8225     9     52.8   76   42    121
#     3     2650   4466    4        6      2989     4     25.7   23    9     44
#
#         output
# sex cp
# 0   0       18
#     1       16
#     2       34
#     3        4
# 1   0       21
#     1       25
#     2       35
#     3       12

# %%
grouped_agg = df.groupby('sex').agg({'chol': ['mean', 'sum'], 'thalachh': 'max'})
grouped_agg
# Out:
#            chol        thalachh
#            mean    sum      max
# sex
# 0    261.302083  25085      192
# 1    239.289855  49533      202

# %%
group_size = df.groupby('sex').size()
group_size
# Out:
# sex
# 0     96
# 1    207
# dtype: int64

# %%
filtered_multi = df[(df['chol'] > 200) & (df['thalachh'] > 150)]
filtered_multi.head()
# Out:
#      sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  caa  \
# age
# 37     1   2     130   250    0        1       187     0      3.5    0    0
# 41     0   1     130   204    0        0       172     0      1.4    2    0
# 56     1   1     120   236    0        1       178     0      0.8    2    0
# 57     0   0     120   354    0        1       163     1      0.6    2    0
# 56     0   1     140   294    0        0       153     0      1.3    1    0
#
#      thall  output
# age
# 37       2       1
# 41       2       1
# 56       2       1
# 57       2       1
# 56       2       1

# %%
query_filtered = df.query('chol > 200 and thalachh > 150')
query_filtered.head()
# Out:
#      sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  caa  \
# age
# 37     1   2     130   250    0        1       187     0      3.5    0    0
# 41     0   1     130   204    0        0       172     0      1.4    2    0
# 56     1   1     120   236    0        1       178     0      0.8    2    0
# 57     0   0     120   354    0        1       163     1      0.6    2    0
# 56     0   1     140   294    0        0       153     0      1.3    1    0
#
#      thall  output
# age
# 37       2       1
# 41       2       1
# 56       2       1
# 57       2       1
# 56       2       1

# %%
isin_filtered = df[df['cp'].isin([0, 1])]
isin_filtered.head()
# Out:
#      sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  caa  \
# age
# 41     0   1     130   204    0        0       172     0      1.4    2    0
# 56     1   1     120   236    0        1       178     0      0.8    2    0
# 57     0   0     120   354    0        1       163     1      0.6    2    0
# 57     1   0     140   192    0        1       148     0      0.4    1    0
# 56     0   1     140   294    0        0       153     0      1.3    1    0
#
#      thall  output
# age
# 41       2       1
# 56       2       1
# 57       2       1
# 57       1       1
# 56       2       1

# %%
df_renamed = df.rename(columns={'cp': 'chest_pain', 'thalachh': 'max_heart_rate'})
df_renamed.head()
# Out:
#      sex  chest_pain  trtbps  chol  fbs  restecg  max_heart_rate  exng  \
# age
# 63     1           3     145   233    1        0             150     0
# 37     1           2     130   250    0        1             187     0
# 41     0           1     130   204    0        0             172     0
# 56     1           1     120   236    0        1             178     0
# 57     0           0     120   354    0        1             163     1
#
#      oldpeak  slp  caa  thall  output
# age
# 63       2.3    0    0      1       1
# 37       3.5    0    0      2       1
# 41       1.4    2    0      2       1
# 56       0.8    2    0      2       1
# 57       0.6    2    0      2       1

# %%
additional_data = pd.DataFrame({
    'age': [29, 60, 45],
    'new_col': [1, 2, 3]
})

# %%
merged_df = pd.merge(df, additional_data, on='age', how='left')
merged_df.head()
# Out:
#    age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0   63    1   3     145   233    1        0       150     0      2.3    0
# 1   37    1   2     130   250    0        1       187     0      3.5    0
# 2   41    0   1     130   204    0        0       172     0      1.4    2
# 3   56    1   1     120   236    0        1       178     0      0.8    2
# 4   57    0   0     120   354    0        1       163     1      0.6    2
#
#    caa  thall  output  new_col
# 0    0      1       1      NaN
# 1    0      2       1      NaN
# 2    0      2       1      NaN
# 3    0      2       1      NaN
# 4    0      2       1      NaN

# %%
concatenated_df = pd.concat([df.head(3), df.tail(3)])
concatenated_df
# Out:
#      sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  caa  \
# age
# 63     1   3     145   233    1        0       150     0      2.3    0    0
# 37     1   2     130   250    0        1       187     0      3.5    0    0
# 41     0   1     130   204    0        0       172     0      1.4    2    0
# 68     1   0     144   193    1        1       141     0      3.4    1    2
# 57     1   0     130   131    0        1       115     1      1.2    1    1
# 57     0   1     130   236    0        0       174     0      0.0    1    1
#
#      thall  output
# age
# 63       1       1
# 37       2       1
# 41       2       1
# 68       3       0
# 57       3       0
# 57       2       0

# %%
melted_df = pd.melt(df.reset_index(), id_vars=['age'], value_vars=['chol', 'thalachh'], var_name='variable', value_name='value')
melted_df.head()
# Out:
#    age variable  value
# 0   63     chol    233
# 1   37     chol    250
# 2   41     chol    204
# 3   56     chol    236
# 4   57     chol    354

# %%
pivot_table = df.pivot_table(values='chol', index='sex', columns='cp', aggfunc='mean') 
pivot_table
# Out:
# cp            0           1           2           3
# sex
# 0    267.538462  251.444444  261.057143  247.000000
# 1    243.605769  241.031250  231.134615  235.052632

# %%
df.to_csv('cleaned_heart.csv', index=False)
print("The cleaned DataFrame has been saved to 'cleaned_heart.csv'.")
# Out:
# The cleaned DataFrame has been saved to 'cleaned_heart.csv'.
