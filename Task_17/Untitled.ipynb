# %% [markdown]
# # Advanced plotting techniques

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('tested.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %% [markdown]
# ### Histogram to understand the Distribution

# %%
import warnings
warnings.filterwarnings("ignore")
for i in df.select_dtypes(include = "number").columns:
    sns.histplot(data = df, x = i)
    plt.show()

# %% [markdown]
# ### Generate a figure with 2x2 subplots

# %%
fig, axs = plt.subplots(2, 2, figsize=(12, 10))

# %% [markdown]
# ### Line plot

# %%
fig, axs = plt.subplots(2, 2, figsize=(12, 10))
axs[0, 0].plot(df['PassengerId'], df['Fare'], label='Fare')
axs[0, 0].set_title('Line Plot')
axs[0, 0].set_xlabel('PassengerId')
axs[0, 0].set_ylabel('Fare')
axs[0, 0].legend()

# %% [markdown]
# ### Scatter plot

# %%
fig, axs = plt.subplots(2, 2, figsize=(12, 10))
axs[0, 1].scatter(df['Age'], df['Fare'], c='blue', label='Fare vs Age')
axs[0, 1].set_title('Scatter Plot')
axs[0, 1].set_xlabel('Age')
axs[0, 1].set_ylabel('Fare')
axs[0, 1].legend()

# %% [markdown]
# ### Bar Plot

# %%
fig, axs = plt.subplots(2, 2, figsize=(12, 10))
df['Pclass'].value_counts().plot(kind='bar', ax=axs[1, 0])
axs[1, 0].set_title('Bar Plot')
axs[1, 0].set_xlabel('Pclass')
axs[1, 0].set_ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# ### Histogram

# %%
fig, axs = plt.subplots(2, 2, figsize=(12, 10))
axs[1, 1].hist(df['Age'].dropna(), bins=20, color='green', alpha=0.7)
axs[1, 1].set_title('Histogram')
axs[1, 1].set_xlabel('Age')
axs[1, 1].set_ylabel('Frequency')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Create a histogram for a given numerical data set

# %%
plt.hist(df['Fare'], bins=30, color='purple', alpha=0.7)
plt.title('Fare Histogram')
plt.xlabel('Fare')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ### Plot multiple histograms on the same figure

# %%
plt.hist(df['Age'].dropna(), bins=20, alpha=0.5, label='Age', color='blue')
plt.hist(df['Fare'], bins=20, alpha=0.5, label='Fare', color='red')
plt.title('Age and Fare Histograms')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.legend()
plt.show()

# %% [markdown]
# ### Normalize the histograms

# %%
plt.hist(df['Age'].dropna(), bins=20, alpha=0.5, density=True, label='Age', color='blue')
plt.hist(df['Fare'], bins=20, alpha=0.5, density=True, label='Fare', color='red')
plt.title('Normalized Age and Fare Histograms')
plt.xlabel('Value')
plt.ylabel('Density')
plt.legend()
plt.show()

# %% [markdown]
# ### Create a box plot for a given numerical data set

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(y=df['Fare'])
plt.title('Box Plot of Fare')
plt.ylabel('Fare')
plt.show()

# %% [markdown]
# ### Generate multiple box plots in a single figure to compare different data sets

# %%
plt.figure(figsize=(12, 8))
sns.boxplot(data=df[['Age', 'Fare']])
plt.title('Box Plot of Age and Fare')
plt.ylabel('Value')
plt.show()

# %% [markdown]
# ### Customize the box plots with titles, labels, and change the colors

# %%
plt.figure(figsize=(12, 8))
sns.boxplot(data=df[['Age', 'Fare']], palette="Set2")
plt.title('Customized Box Plot of Age and Fare')
plt.ylabel('Value')
plt.show()

# %% [markdown]
# # Mini Project

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('tested.csv')

df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
print(df.isnull().sum())
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
print(df.describe())
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   417.000000  417.000000  417.000000  417.000000  417.000000
# mean   1100.635492    0.364508    2.263789   29.525180    0.448441
# std     120.923774    0.481870    0.842077   12.628258    0.897568
# min     892.000000    0.000000    1.000000    0.170000    0.000000
# 25%     996.000000    0.000000    1.000000   23.000000    0.000000
# 50%    1101.000000    0.000000    3.000000   27.000000    0.000000
# 75%    1205.000000    1.000000    3.000000   35.000000    1.000000
# max    1309.000000    1.000000    3.000000   76.000000    8.000000
#
#             Parch        Fare
# count  417.000000  417.000000
# mean     0.393285   35.627188
# std      0.982419   55.907576
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   14.454200
# 75%      0.000000   31.500000
# max      9.000000  512.329200

# %%
sns.countplot(data=df, x='Survived')
plt.title('Survival Count')
plt.show()

# %%
sns.countplot(data=df, x='Pclass')
plt.title('Passenger Class Distribution')
plt.show()

# %%
sns.histplot(df['Age'], bins=30, kde=True)
plt.title('Age Distribution')
plt.show()

# %%
sns.histplot(df['Fare'], bins=30, kde=True)
plt.title('Fare Distribution')
plt.show()

# %%
sns.countplot(data=df, x='Embarked')
plt.title('Embarkation Port Distribution')
plt.show()

# %%
sns.barplot(data=df, x='Sex', y='Survived')
plt.title('Survival Rate by Gender')
plt.show()

# %%
sns.barplot(data=df, x='Pclass', y='Survived')
plt.title('Survival Rate by Class')
plt.show()

# %%
fig, axs = plt.subplots(2, 2, figsize=(12, 10))

axs[0, 0].plot(df['PassengerId'], df['Fare'], label='Fare')
axs[0, 0].set_title('Line Plot')
axs[0, 0].set_xlabel('PassengerId')
axs[0, 0].set_ylabel('Fare')
axs[0, 0].legend()

# %%
fig, axs = plt.subplots(2, 2, figsize=(12, 10))
axs[0, 1].scatter(df['Age'], df['Fare'], c='blue', label='Fare vs Age')
axs[0, 1].set_title('Scatter Plot')
axs[0, 1].set_xlabel('Age')
axs[0, 1].set_ylabel('Fare')
axs[0, 1].legend()

# %%
fig, axs = plt.subplots(2, 2, figsize=(12, 10))

df['Pclass'].value_counts().plot(kind='bar', ax=axs[1, 0])
axs[1, 0].set_title('Bar Plot')
axs[1, 0].set_xlabel('Pclass')
axs[1, 0].set_ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
fig, axs = plt.subplots(2, 2, figsize=(12, 10))

axs[1, 1].hist(df['Age'].dropna(), bins=20, color='green', alpha=0.7)
axs[1, 1].set_title('Histogram')
axs[1, 1].set_xlabel('Age')
axs[1, 1].set_ylabel('Frequency')

plt.tight_layout()
plt.show()

# %%
plt.hist(df['Fare'], bins=30, color='purple', alpha=0.7)
plt.title('Fare Histogram')
plt.xlabel('Fare')
plt.ylabel('Frequency')
plt.show()

# %%
plt.hist(df['Age'].dropna(), bins=20, alpha=0.5, label='Age', color='blue')
plt.hist(df['Fare'], bins=20, alpha=0.5, label='Fare', color='red')
plt.title('Age and Fare Histograms')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.legend()
plt.show()

# %%
plt.hist(df['Age'].dropna(), bins=20, alpha=0.5, density=True, label='Age', color='blue')
plt.hist(df['Fare'], bins=20, alpha=0.5, density=True, label='Fare', color='red')
plt.title('Normalized Age and Fare Histograms')
plt.xlabel('Value')
plt.ylabel('Density')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(y=df['Fare'])
plt.title('Box Plot of Fare')
plt.ylabel('Fare')
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.boxplot(data=df[['Age', 'Fare']])
plt.title('Box Plot of Age and Fare')
plt.ylabel('Value')
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.boxplot(data=df[['Age', 'Fare']], palette="Set2")
plt.title('Customized Box Plot of Age and Fare')
plt.ylabel('Value')
plt.show()
