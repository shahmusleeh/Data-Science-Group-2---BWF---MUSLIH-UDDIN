# %% [markdown]
# # Introduction to Matplotlib (basic plots: line, scatter, bar)

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv ("IMDb_Dataset.csv")

# %%
df
# Out:
#                                              Title  IMDb Rating  Year  \
# 0                                        Gladiator          8.5  2000
# 1    Mission: Impossible - Dead Reckoning Part One          7.7  2023
# 2             Rebel Moon - Part Two: The Scargiver          5.2  2024
# 3                             Inglourious Basterds          8.4  2009
# 4                                      Borderlands          7.1  2024
# ..                                             ...          ...   ...
# 395                            Mother of the Bride          4.8  2024
# 396                        Beetlejuice Beetlejuice          7.1  2024
# 397                                The Idea of You          6.4  2024
# 398                                             IF          6.7  2024
# 399                                   The Fall Guy          7.1  2024
#
#     Certificates      Genre               Director  \
# 0              R     Action           Ridley Scott
# ...

# %%
df.head()
# Out:
#                                            Title  IMDb Rating  Year  \
# 0                                      Gladiator          8.5  2000
# 1  Mission: Impossible - Dead Reckoning Part One          7.7  2023
# 2           Rebel Moon - Part Two: The Scargiver          5.2  2024
# 3                           Inglourious Basterds          8.4  2009
# 4                                    Borderlands          7.1  2024
#
#   Certificates      Genre               Director  \
# 0            R     Action           Ridley Scott
# 1        PG-13     Action  Christopher McQuarrie
# 2        PG-13     Action            Zack Snyder
# 3            R  Adventure      Quentin Tarantino
# 4            R     Action               Eli Roth
#
#                                    Star Cast  MetaScore  Duration (minutes)
# 0  David FranzoniJohn LoganWilliam Nicholson       67.0               155.0
# 1         Tom CruiseHayley AtwellVing Rhames       81.0               163.0
# ...

# %%
df.tail()
# Out:
#                        Title  IMDb Rating  Year Certificates      Genre  \
# 395      Mother of the Bride          4.8  2024        TV-PG     Comedy
# 396  Beetlejuice Beetlejuice          7.1  2024            R     Comedy
# 397          The Idea of You          6.4  2024            R     Comedy
# 398                       IF          6.7  2024           PG  Animation
# 399             The Fall Guy          7.1  2024        PG-13     Action
#
#               Director                                     Star Cast  \
# 395        Mark Waters  Brooke ShieldsMiranda CosgroveBenjamin Bratt
# 396         Tim Burton    Alfred GoughMiles MillarSeth Grahame-Smith
# 397  Michael Showalter     Anne HathawayNicholas GalitzineElla Rubin
# 398     John Krasinski     Cailey FlemingRyan ReynoldsJohn Krasinski
# 399       David Leitch   Ryan GoslingEmily BluntAaron Taylor-Johnson
#
#      MetaScore  Duration (minutes)
# 395       39.0                88.0
# 396       66.9               116.3
# ...

# %% [markdown]
# ### Line Plot

# %%
plt.figure(figsize=(10, 5))
plt.plot(df['Year'], df['IMDb Rating'], label='IMDb Rating')
plt.plot(df['Year'], df['MetaScore'], label='MetaScore', linestyle='--', marker='o')
plt.xlabel('Year')
plt.ylabel('Score')
plt.title('IMDb Rating and MetaScore Over Years')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### Scatter Plot

# %%
plt.figure(figsize=(10, 5))
plt.scatter(df['IMDb Rating'], df['MetaScore'], color='r', label='Movies')
plt.xlabel('IMDb Rating')
plt.ylabel('MetaScore')
plt.title('Scatter Plot: IMDb Rating vs MetaScore')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### Bar Chart

# %%
plt.figure(figsize=(10, 5))
plt.bar(df['Title'], df['IMDb Rating'], color='skyblue', edgecolor='blue')
plt.xlabel('Movie Title')
plt.ylabel('IMDb Rating')
plt.title('Vertical Bar Chart: IMDb Rating for Each Movie')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %% [markdown]
# ### Pie Chart

# %%
genre_counts = df['Genre'].value_counts()
colors = ['lightcoral', 'yellowgreen', 'lightskyblue', 'orange', 'gold', 'purple']
explode = [0.1] + [0] * (len(genre_counts) - 1)

plt.figure(figsize=(8, 8))
plt.pie(genre_counts, labels=genre_counts.index, autopct='%1.1f%%', colors=colors[:len(genre_counts)], explode=explode)
plt.title('Pie Chart: Proportion of Different Genres')
plt.legend(genre_counts.index, loc='upper left')
plt.show()

# %% [markdown]
# # Assigned Tasks

# %% [markdown]
# ### # Simple Line Plot

# %%
plt.figure(figsize=(10, 5))
plt.plot(df['Year'], df['IMDb Rating'])
plt.xlabel('Year')
plt.ylabel('IMDb Rating')
plt.title('IMDb Rating Over Years')
plt.grid(True)
plt.show()

# %% [markdown]
# ### Multiple Lines on the Same Graph

# %%
plt.figure(figsize=(10, 5))
plt.plot(df['Year'], df['IMDb Rating'], label='IMDb Rating')
plt.plot(df['Year'], df['MetaScore'], label='MetaScore')
plt.xlabel('Year')
plt.ylabel('Score')
plt.title('IMDb Rating and MetaScore Over Years')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### Add Markers to a Line Plot

# %%
plt.figure(figsize=(10, 5))
plt.plot(df['Year'], df['IMDb Rating'], marker='o')
plt.xlabel('Year')
plt.ylabel('IMDb Rating')
plt.title('IMDb Rating Over Years with Markers')
plt.grid(True)
plt.show()

# %% [markdown]
# ### Customize Line Styles and Colors

# %%
plt.figure(figsize=(10, 5))
plt.plot(df['Year'], df['IMDb Rating'], label='IMDb Rating', marker='o', linestyle='-', color='blue')
plt.plot(df['Year'], df['MetaScore'], label='MetaScore', marker='x', linestyle='--', color='red')
plt.xlabel('Year')
plt.ylabel('Score')
plt.title('Customized IMDb Rating and MetaScore Over Years')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### Create a Basic Scatter Plot

# %%
plt.figure(figsize=(10, 5))
plt.scatter(df['IMDb Rating'], df['MetaScore'])
plt.xlabel('IMDb Rating')
plt.ylabel('MetaScore')
plt.title('Scatter Plot: IMDb Rating vs MetaScore')
plt.grid(True)
plt.show()

# %% [markdown]
# ### Customize Marker Styles, Sizes, and Colors

# %%
plt.figure(figsize=(10, 5))
plt.scatter(df['IMDb Rating'], df['MetaScore'], marker='o', s=100, c='red', alpha=0.5)
plt.xlabel('IMDb Rating')
plt.ylabel('MetaScore')
plt.title('Customized Scatter Plot: IMDb Rating vs MetaScore')
plt.grid(True)
plt.show()

# %% [markdown]
# ### Plot Multiple Scatter Plots on the Same Graph

# %%
colors = {'Action': 'red', 'Drama': 'blue', 'Comedy': 'green', 'Thriller': 'purple', 'Adventure': 'orange', 'Animation': 'brown', 'Crime': 'black', 'Biography': 'white', 'Horror': 'yellow', 'Fantasy': 'pink'}
plt.figure(figsize=(10, 5))
for genre in df['Genre'].unique():
    subset = df[df['Genre'] == genre]
    plt.scatter(subset['IMDb Rating'], subset['MetaScore'], label=genre, color=colors[genre])
plt.xlabel('IMDb Rating')
plt.ylabel('MetaScore')
plt.title('Scatter Plot: IMDb Rating vs MetaScore by Genre')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### Add Labels and Titles to the Scatter Plot

# %%
plt.figure(figsize=(10, 5))
plt.scatter(df['IMDb Rating'], df['MetaScore'], marker='o', s=100, c='blue', alpha=0.5)
for i in range(len(df)):
    plt.text(df['IMDb Rating'][i], df['MetaScore'][i], df['Title'][i], fontsize=9)
plt.xlabel('IMDb Rating')
plt.ylabel('MetaScore')
plt.title('Scatter Plot with Labels: IMDb Rating vs MetaScore')
plt.grid(True)
plt.show()

# %% [markdown]
# ### Create a Vertical Bar Chart

# %%
plt.figure(figsize=(10, 5))
plt.bar(df['Title'], df['IMDb Rating'], color='skyblue', edgecolor='blue')
plt.xlabel('Movie Title')
plt.ylabel('IMDb Rating')
plt.title('Vertical Bar Chart: IMDb Rating for Each Movie')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %% [markdown]
# ### Create a Horizontal Bar Chart

# %%
plt.figure(figsize=(10, 5))
plt.barh(df['Title'], df['Duration (minutes)'], color='lightgreen', edgecolor='green')
plt.xlabel('Duration (minutes)')
plt.ylabel('Movie Title')
plt.title('Horizontal Bar Chart: Duration for Each Movie')
plt.grid(True)
plt.show()

# %% [markdown]
# ### Customize Bar Colors and Add Edge Colors

# %%
plt.figure(figsize=(10, 5))
plt.bar(df['Title'], df['IMDb Rating'], color='orange', edgecolor='red')
plt.xlabel('Movie Title')
plt.ylabel('IMDb Rating')
plt.title('Customized Vertical Bar Chart: IMDb Rating for Each Movie')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()

# %% [markdown]
# ### Create a Basic Pie Chart

# %%
genre_counts = df['Genre'].value_counts()
plt.figure(figsize=(8, 8))
plt.pie(genre_counts, labels=genre_counts.index, autopct='%1.1f%%')
plt.title('Pie Chart: Proportion of Different Genres')
plt.show()

# %% [markdown]
# ### Customize Slice Colors and Add a Legend

# %%
genre_counts = df['Genre'].value_counts()
colors = ['lightcoral', 'yellowgreen', 'lightskyblue', 'orange', 'gold', 'purple']
plt.figure(figsize=(8, 8))
plt.pie(genre_counts, labels=genre_counts.index, autopct='%1.1f%%', colors=colors[:len(genre_counts)])
plt.title('Pie Chart with Customized Slice Colors')
plt.legend(genre_counts.index, loc='upper left')
plt.show()

# %% [markdown]
# ### Explode a Slice of the Pie Chart

# %%
genre_counts = df['Genre'].value_counts()
colors = ['lightcoral', 'yellowgreen', 'lightskyblue', 'orange', 'gold', 'purple']
explode = [0.1] + [0] * (len(genre_counts) - 1)
plt.figure(figsize=(8, 8))
plt.pie(genre_counts, labels=genre_counts.index, autopct='%1.1f%%', colors=colors[:len(genre_counts)], explode=explode)
plt.title('Pie Chart with an Exploded Slice')
plt.legend(genre_counts.index, loc='upper left')
plt.show()

# %% [markdown]
# ### Add Percentage Labels to Slices

# %%
genre_counts = df['Genre'].value_counts()
colors = ['lightcoral', 'yellowgreen', 'lightskyblue', 'orange', 'gold', 'purple']
explode = [0.1] + [0] * (len(genre_counts) - 1)
plt.figure(figsize=(8, 8))
plt.pie(genre_counts, labels=genre_counts.index, autopct='%1.1f%%', colors=colors[:len(genre_counts)], explode=explode)
plt.title('Pie Chart with Percentage Labels')
plt.legend(genre_counts.index, loc='upper left')
plt.show()

# %% [markdown]
# # Mini Project

# %%
import pandas as pd

url = 'https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv'
df = pd.read_csv(url)

df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
import matplotlib.pyplot as plt

age_counts = df['Age'].value_counts().sort_index()
plt.figure(figsize=(10, 5))
plt.plot(age_counts.index, age_counts.values, label='Number of Passengers', marker='o')
plt.xlabel('Age')
plt.ylabel('Number of Passengers')
plt.title('Number of Passengers Over Ages')
plt.grid(True)
plt.legend()
plt.show()

# %%
age_survival = df.groupby('Age')['Survived'].mean()
plt.figure(figsize=(10, 5))
plt.plot(age_survival.index, age_survival.values, label='Survival Rate', marker='x')
plt.xlabel('Age')
plt.ylabel('Survival Rate')
plt.title('Survival Rate Over Ages')
plt.grid(True)
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10, 5))
colors = {0: 'red', 1: 'blue'}
plt.scatter(df['Age'], df['Fare'], c=df['Survived'].map(colors), alpha=0.5)
plt.xlabel('Age')
plt.ylabel('Fare')
plt.title('Scatter Plot: Fare vs Age')
plt.grid(True)
plt.show()

# %%
class_survival = df.groupby('Pclass')['Survived'].mean()
plt.figure(figsize=(10, 5))
plt.bar(class_survival.index, class_survival.values, color=['skyblue', 'orange', 'green'])
plt.xlabel('Class')
plt.ylabel('Survival Rate')
plt.title('Survival Rate by Class')
plt.grid(True)
plt.show()

# %%
gender_survival = df.groupby('Sex')['Survived'].mean()
plt.figure(figsize=(10, 5))
plt.bar(gender_survival.index, gender_survival.values, color=['purple', 'pink'])
plt.xlabel('Gender')
plt.ylabel('Survival Rate')
plt.title('Survival Rate by Gender')
plt.grid(True)
plt.show()

# %%
survival_counts = df['Survived'].value_counts()
plt.figure(figsize=(8, 8))
plt.pie(survival_counts, labels=['Did Not Survive', 'Survived'], autopct='%1.1f%%', colors=['lightcoral', 'yellowgreen'], explode=[0.1, 0])
plt.title('Proportion of Survivors')
plt.show()
